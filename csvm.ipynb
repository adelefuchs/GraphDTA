# %% [markdown]
# # DAVIS TEST vs PHAROS reclass

# %%
from csvm import main

train_csv = "data/davis_train.csv"
davis_test_csv = "data/davis_test.csv"
davis_pred_csv = "results/1_21/predictions_GINConvNet_davis.csv"
pharos_test_csv = "pharos.csv"
pharos_pred_csv = "results/1_21/predictions_pharos_reclass.csv"

main(train_csv, davis_test_csv, davis_pred_csv, pharos_test_csv, pharos_pred_csv)
# Out:
# Quartile Deviation between true and predicted Davis:  -0.8516142297495355
# Quartile Deviation between true and predicted Pharos:  -2.3289172357217596
# Total distribution shift (just sums):  3.766729365696276
# CSVM =  -0.8516142297495355  -  -2.3289172357217596  /  3.766729365696276
# CSV Metric: 0.39219780943809485
# Train → DAVIS Shift: 0.006493422166836473
# Train → Pharos Shift: 1.8796049931239904
# DAVIS → Pharos Shift: 1.8806309504054493
# Training Data Summary:
# count    25046.000000
# mean         5.451527
# std          0.894606
# min          5.000000
# 25%          5.000000
# 50%          5.000000
# 75%          5.522879
# max         10.795880
# Name: affinity, dtype: float64
#
# DAVIS Test Data Summary:
# count    5010.000000
# mean        5.451571
# std         0.895363
# min         5.000000
# 25%         5.000000
# 50%         5.000000
# 75%         5.522879
# max        10.619789
# Name: affinity, dtype: float64
#
# DAVIS Predictions Summary:
# ...

# %% [markdown]
# # DAVIS test vs DAVUS 20% Blinded

# %%
from csvm import main

regular_train_csv = "data/davis_train.csv"
davis_test_csv = "data/davis_test.csv"
davis_pred_csv = "results/1_21/predictions_GINConvNet_davis.csv"
blinded_train_csv = "davis_blinding/data/davis_b3_train.csv"
pharos_test_csv = "davis_blinding/data/davis_b3_test.csv"
pharos_pred_csv = "davis_blinding/predictions_GINConvNet_davis_b3.csv"

main(train_csv, davis_test_csv, davis_pred_csv, pharos_test_csv, pharos_pred_csv)
